# %% [markdown]
# # Recent Wildfire Detections: A Reproducible Interactive Mapping Workflow
#
# ## Project question
# How can recent wildfire detections be retrieved, cleaned, analysed, and visualised in an interactive web map for a selected study region?
#
# ## Study scope
# - Study area: Southern Europe
# - Time window: Last 30 days
# - Main variables: acquisition date, confidence, brightness, FRP, latitude, longitude
#
# ## Planned output
# - A clean and reproducible notebook
# - A summary of recent wildfire detections
# - An interactive web map with popups
# - A short written interpretation

# %% [markdown]
# ## Mini-workflow
#
# 1. Load wildfire records.
# 2. Keep only relevant columns.
# 3. Clean dates and numeric attributes.
# 4. Convert coordinates into a GeoDataFrame.
# 5. Filter to the study region and recent period.
# 6. Summarise the detections.
# 7. Create an interactive wildfire map with popups.

# %%
# Core libraries
from pathlib import Path
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# Optional helper for nicer tables
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

# %% [markdown]
# ## Why this section?
# This section loads the libraries needed for tabular data handling, spatial data processing, plotting, and interactive mapping.

# %%
# Project structure
PROJECT_DIR = Path.cwd().parent  # adjust if needed
DATA_DIR = PROJECT_DIR / "data"
OUTPUT_DIR = PROJECT_DIR / "outputs"

# Create outputs folder if it does not exist
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("Project directory:", PROJECT_DIR)
print("Data directory:", DATA_DIR)
print("Output directory:", OUTPUT_DIR)

# %% [markdown]
# ## Reproducibility note
# This project uses relative paths so that another student or instructor can run the notebook on a different machine without changing absolute file paths.

# %%
# Study settings
STUDY_AREA_NAME = "Southern Europe"

# Bounding box: west, south, east, north
# You can adjust this later if needed
BBOX = (-10, 35, 30, 48)

# Time filter
DAYS_BACK = 30

# Input file name
WILDFIRE_FILE = DATA_DIR / "wildfires.csv"

print("Study area:", STUDY_AREA_NAME)
print("Bounding box:", BBOX)
print("Input file:", WILDFIRE_FILE)

# %% [markdown]
# ## Study settings
# This section defines the study area, time window, and input dataset.
# Keeping such settings in one place makes the notebook easier to adapt and explain.
